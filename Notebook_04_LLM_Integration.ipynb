# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek28n/Medical-RAG-Hallucination-Detection/blob/main/Notebook_04_LLM_Integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Aug 10 15:56:05 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import os

print("Python environment ready")
print("Current directory:", os.getcwd())
# Out:
# Python environment ready
# Current directory: /content

# %%
import os

print("Python environment ready")
print("Current directory:", os.getcwd())
# Out:
# Python environment ready
# Current directory: /content

# %%
# %cd /content/Medical-RAG-Hallucination-Detection
# !git status
# Out:
# [Errno 2] No such file or directory: '/content/Medical-RAG-Hallucination-Detection'
# /content
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git clone https://github.com/vivek28n/Medical-RAG-Hallucination-Detection.git
# Out:
# Cloning into 'Medical-RAG-Hallucination-Detection'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 66 (delta 30), reused 28 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (66/66), 1.34 MiB | 3.68 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
# %cd /content/Medical-RAG-Hallucination-Detection
# Out:
# /content/Medical-RAG-Hallucination-Detection

# %%
# !pip install -q -U google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 41.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.1/259.1 kB 25.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.56.3 which is incompatible.

# %%
from google import genai

print("Google GenAI imported successfully!")
# Out:
# Google GenAI imported successfully!

# %%
from google.colab import userdata

API_KEY = userdata.get("GEMINI_API_KEY")

print("API key loaded:", API_KEY is not None)
# Out:
# API key loaded: True

# %%
from google import genai

client = genai.Client(api_key=API_KEY)

print("Gemini client created successfully!")
# Out:
# Gemini client created successfully!

# %%
response = client.models.generate_content(
    model="gemini-3.1-flash-lite",
    contents="Say hello and briefly explain what a medical RAG system does."
)

print(response.text)
# Out:
# Hello!
#
# A medical **RAG (Retrieval-Augmented Generation)** system is a specialized AI tool designed to provide highly accurate, evidence-based answers to clinical or health-related questions.
#
# Here is how it works in a nutshell:
#
# 1.  **Retrieval:** Instead of relying solely on the AI's internal training data (which can become outdated), the system searches through a trusted, curated database of medical literature—such as peer-reviewed journals, clinical guidelines, and verified textbooks.
# 2.  **Augmentation:** It pulls the most relevant documents found during that search and provides them to the AI model as context.
# 3.  **Generation:** The AI synthesizes that specific, verified information to generate a concise, accurate answer, always citing the sources it used so that clinicians or users can verify the clinical evidence.
#
# Essentially, it acts as a "super-powered librarian" that ensures medical answers are grounded in current, reliable research rather than just general probabilities.

# %%
print("chunks available:", "chunks" in globals())
print("FAISS index available:", "index" in globals())
print("Embedding model available:", "embedding_model" in globals())
# Out:
# chunks available: False
# FAISS index available: False
# Embedding model available: False

# %%
import os

print("Current directory:", os.getcwd())
print("Vector DB exists:", os.path.exists("vector_db"))

if os.path.exists("vector_db"):
    print("Vector DB files:", os.listdir("vector_db"))
# Out:
# Current directory: /content
# Vector DB exists: False

# %%
# %cd /content/Medical-RAG-Hallucination-Detection

import os

print("Current directory:", os.getcwd())
# Out:
# [Errno 2] No such file or directory: '/content/Medical-RAG-Hallucination-Detection'
# /content
# Current directory: /content

# %%
import os

print("Folders in /content:")
print(os.listdir("/content"))
# Out:
# Folders in /content:
# ['.config', 'sample_data']

# %%
# !git clone https://github.com/vivek28n/Medical-RAG-Hallucination-Detection.git
# Out:
# Cloning into 'Medical-RAG-Hallucination-Detection'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 72 (delta 34), reused 31 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (72/72), 1.34 MiB | 36.12 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
# %cd /content/Medical-RAG-Hallucination-Detection

import os

print("Current directory:", os.getcwd())
print("Notebooks:", os.listdir("notebooks"))
# Out:
# /content/Medical-RAG-Hallucination-Detection
# Current directory: /content/Medical-RAG-Hallucination-Detection
# Notebooks: ['Notebook_01_Project_Setup.ipynb', 'Notebook_02_Environment_Setup.ipynb', 'Notebook_03_PDF_Text_Extraction.ipynb', '.gitkeep', 'Notebook_04_LLM_Integration.ipynb']

# %%
import os

print("Dataset exists:", os.path.exists("dataset"))
print("Raw folder exists:", os.path.exists("dataset/raw"))

if os.path.exists("dataset/raw"):
    print("Raw files:", os.listdir("dataset/raw"))
# Out:
# Dataset exists: True
# Raw folder exists: True
# Raw files: ['niddk_guiding_principles_diabetes.pdf']

# %%
import os

print("Vector DB exists:", os.path.exists("vector_db"))

if os.path.exists("vector_db"):
    print("Vector DB files:", os.listdir("vector_db"))

print("Models exists:", os.path.exists("models"))

if os.path.exists("models"):
    print("Models files:", os.listdir("models"))
# Out:
# Vector DB exists: True
# Vector DB files: ['.gitkeep']
# Models exists: True
# Models files: ['.gitkeep']

# %%
import fitz
import re
import faiss
import numpy as np

from langchain_text_splitters import RecursiveCharacterTextSplitter
from sentence_transformers import SentenceTransformer

print("Packages loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1124/1241576376.py in <cell line: 0>()
# ----> 1 import fitz
#       2 import re
#       3 import faiss
#       4 import numpy as np
#       5
#
# ModuleNotFoundError: No module named 'fitz'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install -q pymupdf
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 80.1 MB/s eta 0:00:00

# %%
import fitz
import re
import faiss
import numpy as np

from langchain_text_splitters import RecursiveCharacterTextSplitter
from sentence_transformers import SentenceTransformer

print("Packages loaded successfully!")
# Out:
# warning: The `fitz` API is deprecated and will be removed in future. Use `import pymupdf` instead.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1124/1241576376.py in <cell line: 0>()
#       1 import fitz
#       2 import re
# ----> 3 import faiss
#       4 import numpy as np
#       5
#
# ModuleNotFoundError: No module named 'faiss'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install -q faiss-cpu
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 77.6 MB/s eta 0:00:00

# %%
import fitz
import re
import faiss
import numpy as np

from langchain_text_splitters import RecursiveCharacterTextSplitter
from sentence_transformers import SentenceTransformer

print("Packages loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1124/1241576376.py in <cell line: 0>()
#       4 import numpy as np
#       5
# ----> 6 from langchain_text_splitters import RecursiveCharacterTextSplitter
#       7 from sentence_transformers import SentenceTransformer
#       8
#
# ModuleNotFoundError: No module named 'langchain_text_splitters'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install -q langchain-text-splitters

# %%
import fitz
import re
import faiss
import numpy as np

from langchain_text_splitters import RecursiveCharacterTextSplitter
from sentence_transformers import SentenceTransformer

print("Packages loaded successfully!")
# Out:
# Packages loaded successfully!

# %%
pdf_path = "dataset/raw/niddk_guiding_principles_diabetes.pdf"

doc = fitz.open(pdf_path)

print("Number of pages:", len(doc))
# Out:
# Number of pages: 83

# %%
text = ""

for page in doc:
    text += page.get_text()

print("Characters extracted:", len(text))
print("\nFirst 1000 characters:\n")
print(text[:1000])
# Out:
# Characters extracted: 201724
#
# First 1000 characters:
#
# 1
# Guiding Principles
# for the Care of People with or at Risk for Diabetes
# 2
# Supporting Organizations
# The Guiding Principles for the Care of People with or at Risk for Diabetes was produced by the
# National Diabetes Education Program (NDEP),* a federally funded program sponsored by the
# U.S. Department of Health and Human Services’ National Institutes of Health and Centers for
# Disease Control and Prevention. NDEP’s partnership network includes more than 200 partners
# working together to improve the treatment and outcomes for people with diabetes, promote early
# diagnosis, and prevent or delay the onset of type 2 diabetes. The following organizations support
# the use of the Guiding Principles for the Care of People with or at Risk for Diabetes:
# • Academy of Nutrition and Dietetics
# • American Academy of Family Physicians
# • American Academy of Physician Assistants
# • American Association of Clinical Endocrinologists
# • American Association of Nurse Practitioners
# • American College of Obstetr

# %%
pages = []

for page_number, page in enumerate(doc, start=1):
    page_text = page.get_text().strip()

    pages.append({
        "page": page_number,
        "text": page_text
    })

print("Total pages processed:", len(pages))
# Out:
# Total pages processed: 83

# %%
def clean_text(text):
    # Multiple spaces ko single space
    text = re.sub(r"[ \t]+", " ", text)

    # Multiple blank lines ko reduce karna
    text = re.sub(r"\n\s*\n+", "\n\n", text)

    # Har line ke extra spaces remove karna
    text = "\n".join(line.strip() for line in text.splitlines())

    return text.strip()


for page in pages:
    page["clean_text"] = clean_text(page["text"])

print("Cleaning completed.")
# Out:
# Cleaning completed.

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunks = []

for page in pages:
    page_chunks = splitter.split_text(page["clean_text"])

    for chunk_id, chunk in enumerate(page_chunks):
        chunks.append({
            "chunk_id": f"page_{page['page']}_chunk_{chunk_id}",
            "page": page["page"],
            "text": chunk
        })

print("Total chunks:", len(chunks))
# Out:
# Total chunks: 277

# %%
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

print("Embedding model loaded successfully!")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Embedding model loaded successfully!

# %%
chunk_texts = [chunk["text"] for chunk in chunks]

embeddings = embedding_model.encode(
    chunk_texts,
    show_progress_bar=True
)

print("Total embeddings:", len(embeddings))
print("Embedding dimensions:", embeddings.shape[1])
# Out:
# Batches:   0%|          | 0/9 [00:00<?, ?it/s]
# Total embeddings: 277
# Embedding dimensions: 384

# %%
embedding_array = np.array(embeddings).astype("float32")

print("Embedding shape:", embedding_array.shape)

dimension = embedding_array.shape[1]

index = faiss.IndexFlatL2(dimension)
index.add(embedding_array)

print("Total vectors in FAISS:", index.ntotal)
# Out:
# Embedding shape: (277, 384)
# Total vectors in FAISS: 277

# %%
query = "What are the risk factors for diabetes?"

query_embedding = embedding_model.encode([query])
query_embedding = np.array(query_embedding).astype("float32")

distances, indices = index.search(query_embedding, k=5)

print("Retrieved indices:", indices[0])
print("Distances:", distances[0])
# Out:
# Retrieved indices: [  7  23   8 250   0]
# Distances: [0.6567526  0.67704546 0.7259886  0.74482733 0.74978113]

# %%
for rank, idx in enumerate(indices[0], start=1):
    print(f"\n--- Retrieved Result {rank} ---")
    print("Chunk ID:", chunks[idx]["chunk_id"])
    print("Page:", chunks[idx]["page"])
    print("Distance:", distances[0][rank - 1])
    print("\nText:")
    print(chunks[idx]["text"][:1000])
# Out:
# --- Retrieved Result 1 ---
# Chunk ID: page_5_chunk_0
# Page: 5
# Distance: 0.6567526
#
# Text:
# 5
# INTRODUCTION
# The diabetes problem
# Today, 30.3 million people (9.4 percent of the U.S. population) have diabetes, including 7.2 million
# who are undiagnosed.1 A major cause of blindness, renal failure, and amputation, diabetes
# also increases the risk of cardiovascular disease, cancer, and dementia and more than doubles
# individual health care costs.2 The total estimated cost of diagnosed diabetes in 2017 was $327
# billion, including $237 billion in direct medical costs and $90 billion in reduced productivity.2
# Another 84.1 million Americans (33.9 percent of adults) have glucose levels that are higher than
# normal but not high enough to be characterized as diabetes.1 Because persons with these glucose
# levels are at increased risk of developing type 2 diabetes, this condition is termed prediabetes
# by the Centers for Disease Control and Prevention (CDC) and other organizations.
# Proper nutrition and physical activity are the cornerstones of treatment and prevention of type 2
#
# --- Retrieved Result 2 ---
# Chunk ID: page_9_chunk_0
# Page: 9
# Distance: 0.67704546
#
# Text:
# 9
# Adapted from American Diabetes Association Standards of Care in Diabetes—2018
# Risk of type 2 diabetes increases with age
# and is strongly associated with overweight or
# obesity—body mass index (BMI) ≥ 25 kg/m2
# (≥ 23 kg/m2 for Asian Americans5)
#
# Additional risk factors include
# 1.
#
# 2.
#
# 3.
# 4.
# 5.
# Family history of diabetes (i.e., parent
# or sibling)
# Member of high-risk population: African
# American, Hispanic/Latino, American
# Indian, Alaska Native, Asian American,
# Pacific Islander American
# History of GDM
# Physical inactivity
# Hypertension
# Obstructive sleep apnea and chronic sleep
# deprivation (< 6 hours/day) are emerging
# risk factors.
# 6.
#
# 7.
#
# 8.
#
# --- Retrieved Result 3 ---
# Chunk ID: page_5_chunk_1
# Page: 5
# Distance: 0.7259886
#
# Text:
# by the Centers for Disease Control and Prevention (CDC) and other organizations.
# Proper nutrition and physical activity are the cornerstones of treatment and prevention of type 2
# diabetes. In addition to lifestyle modifications and tobacco avoidance, controlling blood glucose,
# blood pressure, and cholesterol dramatically improves health outcomes. As a result of improved
# risk factor control, rates of complications, particularly for cardiovascular disease, have declined
# among people with diabetes.3
# Yet diabetes management is suboptimal, particularly in disproportionately affected poor and
# minority populations.4 Analysis of national survey data from 1999 to 2010 for adults with diabetes
# found improvement in glycemic control, blood pressure, and blood lipids. However, 22 percent
# of adults with diabetes have A1C > 8; 28 percent have BP > 140/90; 51 percent are on statins; 44
# percent have LDL > 100; and 20 percent use tobacco. Thus, a substantial proportion of people with
#
# --- Retrieved Result 4 ---
# Chunk ID: page_75_chunk_4
# Page: 75
# Distance: 0.74482733
#
# Text:
# complications. Fourteen percent of youth with type 1 diabetes and 92 percent of youth with
# type 2 diabetes have more than two CVD risk factors.9,10 Overweight and obesity in children are
# GUIDING PRINCIPLES FOR THE CARE OF PEOPLE WITH OR AT RISK FOR DIABETES | PRINCIPLE 10
#
# --- Retrieved Result 5 ---
# Chunk ID: page_1_chunk_0
# Page: 1
# Distance: 0.74978113
#
# Text:
# 1
# Guiding Principles
# for the Care of People with or at Risk for Diabetes

# %%
retrieved_context = ""

for rank, idx in enumerate(indices[0], start=1):
    retrieved_context += f"""
--- Evidence {rank} ---
Source page: {chunks[idx]["page"]}
Chunk ID: {chunks[idx]["chunk_id"]}

{chunks[idx]["text"]}
"""

print(retrieved_context)
# Out:
# --- Evidence 1 ---
# Source page: 5
# Chunk ID: page_5_chunk_0
#
# 5
# INTRODUCTION
# The diabetes problem
# Today, 30.3 million people (9.4 percent of the U.S. population) have diabetes, including 7.2 million
# who are undiagnosed.1 A major cause of blindness, renal failure, and amputation, diabetes
# also increases the risk of cardiovascular disease, cancer, and dementia and more than doubles
# individual health care costs.2 The total estimated cost of diagnosed diabetes in 2017 was $327
# billion, including $237 billion in direct medical costs and $90 billion in reduced productivity.2
# Another 84.1 million Americans (33.9 percent of adults) have glucose levels that are higher than
# normal but not high enough to be characterized as diabetes.1 Because persons with these glucose
# levels are at increased risk of developing type 2 diabetes, this condition is termed prediabetes
# by the Centers for Disease Control and Prevention (CDC) and other organizations.
# Proper nutrition and physical activity are the cornerstones of treatment and prevention of type 2
#
# --- Evidence 2 ---
# Source page: 9
# Chunk ID: page_9_chunk_0
#
# 9
# Adapted from American Diabetes Association Standards of Care in Diabetes—2018
# Risk of type 2 diabetes increases with age
# and is strongly associated with overweight or
# obesity—body mass index (BMI) ≥ 25 kg/m2
# (≥ 23 kg/m2 for Asian Americans5)
#
# Additional risk factors include
# 1.
#
# 2.
#
# 3.
# 4.
# 5.
# Family history of diabetes (i.e., parent
# or sibling)
# Member of high-risk population: African
# American, Hispanic/Latino, American
# Indian, Alaska Native, Asian American,
# Pacific Islander American
# History of GDM
# Physical inactivity
# Hypertension
# Obstructive sleep apnea and chronic sleep
# deprivation (< 6 hours/day) are emerging
# risk factors.
# 6.
#
# 7.
#
# 8.
#
# --- Evidence 3 ---
# Source page: 5
# Chunk ID: page_5_chunk_1
#
# by the Centers for Disease Control and Prevention (CDC) and other organizations.
# Proper nutrition and physical activity are the cornerstones of treatment and prevention of type 2
# diabetes. In addition to lifestyle modifications and tobacco avoidance, controlling blood glucose,
# blood pressure, and cholesterol dramatically improves health outcomes. As a result of improved
# risk factor control, rates of complications, particularly for cardiovascular disease, have declined
# among people with diabetes.3
# Yet diabetes management is suboptimal, particularly in disproportionately affected poor and
# minority populations.4 Analysis of national survey data from 1999 to 2010 for adults with diabetes
# found improvement in glycemic control, blood pressure, and blood lipids. However, 22 percent
# of adults with diabetes have A1C > 8; 28 percent have BP > 140/90; 51 percent are on statins; 44
# percent have LDL > 100; and 20 percent use tobacco. Thus, a substantial proportion of people with
#
# --- Evidence 4 ---
# Source page: 75
# Chunk ID: page_75_chunk_4
#
# complications. Fourteen percent of youth with type 1 diabetes and 92 percent of youth with
# type 2 diabetes have more than two CVD risk factors.9,10 Overweight and obesity in children are
# GUIDING PRINCIPLES FOR THE CARE OF PEOPLE WITH OR AT RISK FOR DIABETES | PRINCIPLE 10
#
# --- Evidence 5 ---
# Source page: 1
# Chunk ID: page_1_chunk_0
#
# 1
# Guiding Principles
# for the Care of People with or at Risk for Diabetes

# %%
prompt = f"""
You are a medical information assistant.

Answer the user's question using ONLY the provided evidence.
Do not add information that is not supported by the evidence.
If the evidence is insufficient, clearly say that the evidence is insufficient.

User question:
{query}

Retrieved medical evidence:
{retrieved_context}

Instructions:
- Give a concise answer.
- Mention the relevant source page numbers.
- Do not invent medical facts.
"""

response = client.models.generate_content(
    model="gemini-3.1-flash-lite",
    contents=prompt
)

print(response.text)
# Out:
# Based on the provided evidence, the risk factors for type 2 diabetes include:
#
# *   **Age:** Risk increases with age (page 9).
# *   **Weight:** Being overweight or obese (defined as a BMI ≥ 25 kg/m², or ≥ 23 kg/m² for Asian Americans) (page 9).
# *   **Family History:** Having a parent or sibling with diabetes (page 9).
# *   **High-Risk Populations:** Being African American, Hispanic/Latino, American Indian, Alaska Native, Asian American, or Pacific Islander American (page 9).
# *   **Medical History:** Having a history of gestational diabetes mellitus (GDM) (page 9).
# *   **Lifestyle Factors:** Physical inactivity (page 9).
# *   **Health Conditions:** Hypertension (page 9).
# *   **Sleep Issues:** Obstructive sleep apnea and chronic sleep deprivation (less than 6 hours/day) (page 9).
# *   **Prediabetes:** Having glucose levels higher than normal but not high enough to be characterized as diabetes (page 5).

# %%
import os

notebook_path = "notebooks/Notebook_04_LLM_Integration.ipynb"

print("Notebook exists:", os.path.exists(notebook_path))
print("Notebook path:", notebook_path)
# Out:
# Notebook exists: True
# Notebook path: notebooks/Notebook_04_LLM_Integration.ipynb

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git log -1 --oneline
# Out:
# 969c734 (HEAD -> main, origin/main, origin/HEAD) Move Notebook 4 into notebooks directory

# %%
# %cd /content/Medical-RAG-Hallucination-Detection
# Out:
# /content/Medical-RAG-Hallucination-Detection

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !find /content -name "Notebook_04_LLM_Integration.ipynb"
# Out:
# /content/Medical-RAG-Hallucination-Detection/notebooks/Notebook_04_LLM_Integration.ipynb

# %%
# !git add notebooks/Notebook_04_LLM_Integration.ipynb
# !git commit -m "Update Notebook 4 LLM Integration"
# !git push origin main
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@66c035c4a6c3.(none)')
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.name "Mansi Sharma"
# !git config --global user.email "mansisharmapt6@gmail.com"

# %%
# !git config --global user.name
# !git config --global user.email
# Out:
# Mansi Sharma
# mansisharmapt6@gmail.com

# %%
# %cd /content/Medical-RAG-Hallucination-Detection

# !git add notebooks/Notebook_04_LLM_Integration.ipynb
# !git commit -m "Update Notebook 4 LLM Integration"
# Out:
# /content/Medical-RAG-Hallucination-Detection
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
import os

path = "/content/Medical-RAG-Hallucination-Detection/notebooks/Notebook_04_LLM_Integration.ipynb"

print("Exists:", os.path.exists(path))
print("Size:", os.path.getsize(path), "bytes")
# Out:
# Exists: True
# Size: 6948 bytes

# %%
# !git diff -- notebooks/Notebook_04_LLM_Integration.ipynb

# %%
# !find /content -name "Notebook_04_LLM_Integration.ipynb" -type f
# Out:
# /content/Medical-RAG-Hallucination-Detection/notebooks/Notebook_04_LLM_Integration.ipynb

# %%
# %cd /content/Medical-RAG-Hallucination-Detection

# !git status
# Out:
# /content/Medical-RAG-Hallucination-Detection
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# %cd /content/Medical-RAG-Hallucination-Detection

# !git status
# !git diff --stat
# !git ls-files -v notebooks/Notebook_04_LLM_Integration.ipynb
# Out:
# /content/Medical-RAG-Hallucination-Detection
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# H notebooks/Notebook_04_LLM_Integration.ipynb

# %%
import json

path = "/content/Medical-RAG-Hallucination-Detection/notebooks/Notebook_04_LLM_Integration.ipynb"

with open(path, "r", encoding="utf-8") as f:
    nb = json.load(f)

print("Cells:", len(nb["cells"]))

for i, cell in enumerate(nb["cells"]):
    if cell["cell_type"] == "code":
        source = "".join(cell["source"])
        print(f"\n--- Code Cell {i} ---")
        print(source[:300])
# Out:
# Cells: 7
#
# --- Code Cell 1 ---
# !nvidia-smi
#
# --- Code Cell 2 ---
# import os
#
# print("Python environment ready")
# print("Current directory:", os.getcwd())
#
# --- Code Cell 3 ---
# import os
#
# print("Python environment ready")
# print("Current directory:", os.getcwd())
#
# --- Code Cell 4 ---
# %cd /content/Medical-RAG-Hallucination-Detection
# !git status
#
#
# --- Code Cell 5 ---
# !git clone https://github.com/vivek28n/Medical-RAG-Hallucination-Detection.git
#
# --- Code Cell 6 ---
# %cd /content/Medical-RAG-Hallucination-Detection

# %%
import os

print("Current directory:", os.getcwd())
print("Notebook file exists:",
      os.path.exists("/content/Medical-RAG-Hallucination-Detection/notebooks/Notebook_04_LLM_Integration.ipynb"))
# Out:
# Current directory: /content/Medical-RAG-Hallucination-Detection
# Notebook file exists: True

# %%
import json

path = "/content/Medical-RAG-Hallucination-Detection/notebooks/Notebook_04_LLM_Integration.ipynb"

with open(path, "r", encoding="utf-8") as f:
    nb = json.load(f)

print("Number of cells:", len(nb["cells"]))

for i, cell in enumerate(nb["cells"]):
    print(i, cell["cell_type"], "".join(cell["source"])[:100].replace("\n", " "))
# Out:
# Number of cells: 7
# 0 markdown <a href="https://colab.research.google.com/github/vivek28n/Medical-RAG-Hallucination-Detection/blob/
# 1 code !nvidia-smi
# 2 code import os  print("Python environment ready") print("Current directory:", os.getcwd())
# 3 code import os  print("Python environment ready") print("Current directory:", os.getcwd())
# 4 code %cd /content/Medical-RAG-Hallucination-Detection !git status
# 5 code !git clone https://github.com/vivek28n/Medical-RAG-Hallucination-Detection.git
# 6 code %cd /content/Medical-RAG-Hallucination-Detection

# %%
# !git commit -m "Update Notebook 4 with today's work"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
import os

print("Current directory:", os.getcwd())
# !pwd
# !ls -lh /content/Medical-RAG-Hallucination-Detection/notebooks/
# Out:
# Current directory: /content/Medical-RAG-Hallucination-Detection
# /content/Medical-RAG-Hallucination-Detection
# total 256K
# -rw-r--r-- 1 root root 7.3K Aug 11 16:10 Notebook_01_Project_Setup.ipynb
# -rw-r--r-- 1 root root 9.5K Aug 11 16:10 Notebook_02_Environment_Setup.ipynb
# -rw-r--r-- 1 root root 227K Aug 11 16:10 Notebook_03_PDF_Text_Extraction.ipynb
# -rw-r--r-- 1 root root 6.8K Aug 11 16:10 Notebook_04_LLM_Integration.ipynb

# %%
import json

path = "/content/Medical-RAG-Hallucination-Detection/notebooks/Notebook_04_LLM_Integration.ipynb"

with open(path, "r", encoding="utf-8") as f:
    nb = json.load(f)

print("Cells in GitHub repository copy:", len(nb["cells"]))
# Out:
# Cells in GitHub repository copy: 7

# %%
# !git commit -m "Update Notebook 4 with today's changes"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.name "Mansi Sharma"

# %%
# !git remote set-url origin https://YOUR_USERNAME@github.com/vivek28n/Medical-RAG-Hallucination-Detection.git

# %%
# !git push origin main
# Out:
# fatal: could not read Password for 'https://YOUR_USERNAME@github.com': No such device or address

# %%
# !git remote set-url origin https://mansisharmapt6@github.com/vivek28n/Medical-RAG-Hallucination-Detection.git

# %%
# !git push origin main
# Out:
# fatal: could not read Password for 'https://mansisharmapt6@github.com': No such device or address

# %%
# Cell 1: Verify required packages

import importlib.util

packages = {
    "google-genai": "google.genai",
    "faiss": "faiss",
    "sentence-transformers": "sentence_transformers",
    "pymupdf": "fitz",
    "langchain": "langchain",
    "fastapi": "fastapi"
}

for package_name, module_name in packages.items():
    if importlib.util.find_spec(module_name):
        print(f"✅ {package_name} is installed")
    else:
        print(f"❌ {package_name} is NOT installed")
# Out:
# ✅ google-genai is installed
# ❌ faiss is NOT installed
# ✅ sentence-transformers is installed
# ❌ pymupdf is NOT installed
# ✅ langchain is installed
# ✅ fastapi is installed

# %%
# Cell 2: Install missing packages

# !pip install -q faiss-cpu pymupdf

print("✅ FAISS and PyMuPDF installation completed.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 96.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 84.7 MB/s eta 0:00:00
# ✅ FAISS and PyMuPDF installation completed.

# %%
# Cell 3: Check existing RAG variables

required_variables = [
    "chunks",
    "index",
    "embedding_model",
    "client"
]

print("Checking existing Notebook 4 variables...\n")

for variable in required_variables:
    if variable in globals():
        print(f"✅ {variable} is available")
    else:
        print(f"❌ {variable} is missing")
# Out:
# Checking existing Notebook 4 variables...
#
# ❌ chunks is missing
# ❌ index is missing
# ❌ embedding_model is missing
# ❌ client is missing

# %%
# Cell 4: Load the existing medical PDF

import fitz
import os

PDF_PATH = "dataset/raw/niddk_guiding_principles_diabetes.pdf"

if os.path.exists(PDF_PATH):
    print("✅ PDF found")
    print("Path:", PDF_PATH)
else:
    print("❌ PDF not found")
    print("Current directory:", os.getcwd())
# Out:
# warning: The `fitz` API is deprecated and will be removed in future. Use `import pymupdf` instead.
# ❌ PDF not found
# Current directory: /content

# %%
# Cell 5: Check existing files and folders

import os

print("Current directory:", os.getcwd())
print("\nContents of /content:\n")

for item in os.listdir("/content"):
    print(item)
# Out:
# Current directory: /content
#
# Contents of /content:
#
# .config
# sample_data

# %%
# Cell 6: Clone the existing project repository

# !git clone https://github.com/vivek28n/Medical-RAG-Hallucination-Detection.git

print("✅ Repository cloned successfully")
# Out:
# Cloning into 'Medical-RAG-Hallucination-Detection'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 80 (delta 39), reused 34 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (80/80), 1.36 MiB | 26.20 MiB/s, done.
# Resolving deltas: 100% (39/39), done.
# ✅ Repository cloned successfully

# %%
# Cell 7: Move into the existing project

# %cd /content/Medical-RAG-Hallucination-Detection

print("✅ Current project directory:")
# !pwd
# Out:
# /content/Medical-RAG-Hallucination-Detection
# ✅ Current project directory:
# /content/Medical-RAG-Hallucination-Detection

# %%
# Cell 8: Verify existing project files

# !find . -maxdepth 3 -type f | sort
# Out:
# ./assets/.gitkeep
# ./backend/.gitkeep
# ./dataset/.gitkeep
# ./dataset/raw/niddk_guiding_principles_diabetes.pdf
# ./docs/.gitkeep
# ./docs/PROJECT_PLAN.md
# ./docs/ROADMAP.md
# ./docs/TEAM_GUIDELINES.md
# ./docs/TEAM_HANDOFF.md
# ./frontend/.gitkeep
# ./.git/config
# ./.git/description
# ./.git/HEAD
# ./.git/hooks/applypatch-msg.sample
# ./.git/hooks/commit-msg.sample
# ./.git/hooks/fsmonitor-watchman.sample
# ./.git/hooks/post-update.sample
# ./.git/hooks/pre-applypatch.sample
# ./.git/hooks/pre-commit.sample
# ./.git/hooks/pre-merge-commit.sample
# ./.git/hooks/prepare-commit-msg.sample
# ./.git/hooks/pre-push.sample
# ./.git/hooks/pre-rebase.sample
# ./.git/hooks/pre-receive.sample
# ./.git/hooks/push-to-checkout.sample
# ./.git/hooks/update.sample
# ./.gitignore
# ./.git/index
# ./.git/info/exclude
# ./.git/logs/HEAD
# ./.git/packed-refs
# ./LICENSE
# ./models/.gitkeep
# ./notebooks/.gitkeep
# ./notebooks/Notebook_01_Project_Setup.ipynb
# ./notebooks/Notebook_02_Environment_Setup.ipynb
# ./notebooks/Notebook_03_PDF_Text_Extraction.ipynb
# ./notebooks/Notebook_04_LLM_Integration.ipynb
# ./outputs/.gitkeep
# ./presentation/.gitkeep
# ./README.md
# ./research/.gitkeep
# ./screenshots/.gitkeep
# ./scripts/.gitkeep
# ./tests/.gitkeep
# ./vector_db/.gitkeep

# %%
# Cell 9: Go to notebooks directory

# %cd /content/Medical-RAG-Hallucination-Detection/notebooks

print("✅ Current directory:")
# !pwd
# Out:
# /content/Medical-RAG-Hallucination-Detection/notebooks
# ✅ Current directory:
# /content/Medical-RAG-Hallucination-Detection/notebooks

# %%
# Cell 10: Check Notebook 3

import json

notebook_path = "Notebook_03_PDF_Text_Extraction.ipynb"

with open(notebook_path, "r", encoding="utf-8") as f:
    notebook3 = json.load(f)

print("Total cells in Notebook 3:", len(notebook3["cells"]))

for i, cell in enumerate(notebook3["cells"]):
    source = "".join(cell.get("source", []))
    print(f"\n--- Cell {i + 1} ({cell['cell_type']}) ---")
    print(source[:500])
# Out:
# Total cells in Notebook 3: 28
#
# --- Cell 1 (code) ---
# !git clone https://github.com/vivek28n/Medical-RAG-Hallucination-Detection.git
#
# --- Cell 2 (code) ---
# %cd /content/Medical-RAG-Hallucination-Detection
#
# --- Cell 3 (code) ---
# import os
#
# print("Dataset:", os.path.exists("dataset"))
# print("Raw:", os.path.exists("dataset/raw"))
# print("Files:", os.listdir("dataset/raw"))
#
# --- Cell 4 (code) ---
# !git pull origin main
#
# --- Cell 5 (code) ---
# import os
# print(os.listdir("dataset/raw"))
#
# --- Cell 6 (code) ---
# !pip install -q pymupdf
#
# --- Cell 7 (code) ---
# import os
#
# print(os.getcwd())
# print(os.listdir("dataset/raw"))
#
# --- Cell 8 (code) ---
# import fitz
#
# pdf_path = "dataset/raw/niddk_guiding_principles_diabetes.pdf"
#
# doc = fitz.open(pdf_path)
#
# print("Number of pages:", len(doc))
#
# --- Cell 9 (code) ---
# text = ""
#
# for page in doc:
#     text += page.get_text()
#
# print("Characters extracted:", len(text))
# print("\nFirst 3000 characters:\n")
# print(text[:3000])
#
# --- Cell 10 (code) ---
# print("Total characters:", len(text))
# print("Total words:", len(text.split()))
# print("First 1000 characters:")
# print(text[:1000])
#
# --- Cell 11 (code) ---
# pages = []
#
# for page_number, page in enumerate(doc, start=1):
#     page_text = page.get_text().strip()
#
#     pages.append({
#         "page": page_number,
#         "text": page_text
#     })
#
# print("Total pages processed:", len(pages))
#
# --- Cell 12 (code) ---
# print("Page number:", pages[0]["page"])
# print("Characters:", len(pages[0]["text"]))
# print("\nPage text:\n")
# print(pages[0]["text"][:2000])
#
# --- Cell 13 (code) ---
# import re
#
# def clean_text(text):
#     # Multiple spaces ko single space
#     text = re.sub(r"[ \t]+", " ", text)
#
#     # Multiple blank lines ko single newline
#     text = re.sub(r"\n\s*\n+", "\n\n", text)
#
#     # Har line ke beginning/end ke extra spaces
#     text = "\n".join(line.strip() for line in text.splitlines())
#
#     return text.strip()
#
#
# for page in pages:
#     page["clean_text"] = clean_text(page["text"])
#
# print("Cleaning completed.")
#
# --- Cell 14 (code) ---
# print("Original characters:", len(pages[0]["text"]))
# print("Cleaned characters:", len(pages[0]["clean_text"]))
#
# print("\nCleaned page preview:\n")
# print(pages[0]["clean_text"][:2000])
#
# --- Cell 15 (code) ---
# !pip install -q langchain-text-splitters
#
# --- Cell 16 (code) ---
# from langchain_text_splitters import RecursiveCharacterTextSplitter
#
# splitter = RecursiveCharacterTextSplitter(
#     chunk_size=1000,
#     chunk_overlap=200
# )
#
# print("Text splitter ready!")
#
# --- Cell 17 (code) ---
# chunks = []
#
# for page in pages:
#     page_chunks = splitter.split_text(page["clean_text"])
#
#     for chunk_id, chunk in enumerate(page_chunks):
#         chunks.append({
#             "chunk_id": f"page_{page['page']}_chunk_{chunk_id}",
#             "page": page["page"],
#             "text": chunk
#         })
#
# print("Total chunks:", len(chunks))
#
# --- Cell 18 (code) ---
# print("Chunk ID:", chunks[0]["chunk_id"])
# print("Page:", chunks[0]["page"])
# print("Characters:", len(chunks[0]["text"]))
# print("\nChunk:\n")
# print(chunks[0]["text"])
#
# --- Cell 19 (code) ---
# print("Chunk ID:", chunks[100]["chunk_id"])
# print("Page:", chunks[100]["page"])
# print("Characters:", len(chunks[100]["text"]))
# print("\nChunk:\n")
# print(chunks[100]["text"])
#
# --- Cell 20 (code) ---
# from sentence_transformers import SentenceTransformer
#
# embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
#
# print("Embedding model loaded successfully!")
#
# --- Cell 21 (code) ---
# test_embedding = embedding_model.encode(chunks[0]["text"])
#
# print("Embedding type:", type(test_embedding))
# print("Embedding dimensions:", len(test_embedding))
#
# --- Cell 22 (code) ---
# chunk_texts = [chunk["text"] for chunk in chunks]
#
# embeddings = embedding_model.encode(
#     chunk_texts,
#     show_progress_bar=True
# )
#
# print("Total embeddings:", len(embeddings))
# print("Embedding dimensions:", embeddings.shape[1])
#
# --- Cell 23 (code) ---
# !pip install -q faiss-cpu
#
# --- Cell 24 (code) ---
# import faiss
# import numpy as np
#
# embedding_array = np.array(embeddings).astype("float32")
#
# print("Embedding shape:", embedding_array.shape)
#
# --- Cell 25 (code) ---
# dimension = embedding_array.shape[1]
#
# index = faiss.IndexFlatL2(dimension)
# index.add(embedding_array)
#
# print("Total vectors in FAISS:", index.ntotal)
#
# --- Cell 26 (code) ---
# query = "What are the risk factors for diabetes?"
#
# query_embedding = embedding_model.encode([query])
# query_embedding = np.array(query_embedding).astype("float32")
#
# print("Query embedding shape:", query_embedding.shape)
#
# --- Cell 27 (code) ---
# distances, indices = index.search(query_embedding, k=5)
#
# print("Retrieved indices:", indices[0])
# print("Distances:", distances[0])
#
# --- Cell 28 (code) ---
# for rank, idx in enumerate(indices[0], start=1):
#     print(f"\n--- Result {rank} ---")
#     print("Chunk ID:", chunks[idx]["chunk_id"])
#     print("Page:", chunks[idx]["page"])
#     print("Distance:", distances[0][rank - 1])
#     print("\n", chunks[idx]["text"][:1000])

# %%
# Cell 11: Execute existing Notebook 3 pipeline
# This only loads its existing code into the current Colab runtime.

import os
import nbformat

notebook_path = "/content/Medical-RAG-Hallucination-Detection/notebooks/Notebook_03_PDF_Text_Extraction.ipynb"

with open(notebook_path, "r", encoding="utf-8") as f:
    nb = nbformat.read(f, as_version=4)

# Skip Git clone/pull cells and package-install cells.
# We already have the repository and installed packages.
cells_to_run = []

for i, cell in enumerate(nb.cells):
    source = cell.get("source", "")

    if cell["cell_type"] != "code":
        continue

    # Skip cells that clone/pull the repository
    if "!git clone" in source or "!git pull" in source:
        continue

    # Skip installation cells
    if "!pip install" in source:
        continue

    cells_to_run.append((i, source))

print("Running Notebook 3 processing cells...\n")

for original_index, source in cells_to_run:
    print(f"========== Notebook 3 Cell {original_index + 1} ==========")
    exec(source, globals())
    print()

print("✅ Existing Notebook 3 pipeline executed.")
# Out:
# Running Notebook 3 processing cells...
#
# ========== Notebook 3 Cell 2 ==========
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/tmp/ipykernel_2004/146008469.py", line 36, in <cell line: 0>
#     exec(source, globals())
#
#   File "<string>", line 1
#     %cd /content/Medical-RAG-Hallucination-Detection
#     ^
# SyntaxError: invalid syntax

# %%
# Cell 11: Execute the existing Notebook 3 processing pipeline

import nbformat

notebook_path = "/content/Medical-RAG-Hallucination-Detection/notebooks/Notebook_03_PDF_Text_Extraction.ipynb"

with open(notebook_path, "r", encoding="utf-8") as f:
    nb = nbformat.read(f, as_version=4)

print("Running existing Notebook 3 processing cells...\n")

for i, cell in enumerate(nb.cells):

    if cell["cell_type"] != "code":
        continue

    source = cell["source"]

    # Skip Git commands
    if "!git clone" in source or "!git pull" in source:
        continue

    # Skip package installation cells
    if "!pip install" in source:
        continue

    # Skip Colab/Jupyter magic commands such as %cd
    if source.strip().startswith("%"):
        continue

    print(f"========== Notebook 3 Cell {i + 1} ==========")

    exec(source, globals())

    print()

print("✅ Notebook 3 pipeline loaded successfully.")
# Out:
# Running existing Notebook 3 processing cells...
#
# ========== Notebook 3 Cell 3 ==========
# Dataset: False
# Raw: False
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2004/352036923.py in <cell line: 0>()
#      31     print(f"========== Notebook 3 Cell {i + 1} ==========")
#      32
# ---> 33     exec(source, globals())
#      34
#      35     print()
#
# <string> in <module>
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/raw'

# %%
# Cell 11: Restore the existing Notebook 3 pipeline
# This does NOT modify Notebook 3.

import nbformat
import os

PROJECT_DIR = "/content/Medical-RAG-Hallucination-Detection"
NOTEBOOK3 = os.path.join(
    PROJECT_DIR,
    "notebooks",
    "Notebook_03_PDF_Text_Extraction.ipynb"
)

# Move into the existing project
# %cd /content/Medical-RAG-Hallucination-Detection

# Read existing Notebook 3
with open(NOTEBOOK3, "r", encoding="utf-8") as f:
    nb = nbformat.read(f, as_version=4)

print("Restoring existing Notebook 3 pipeline...\n")

for i, cell in enumerate(nb.cells):

    if cell["cell_type"] != "code":
        continue

    source = cell["source"]

    # Do NOT clone or pull again
    if "!git clone" in source or "!git pull" in source:
        continue

    # Packages are already installed
    if "!pip install" in source:
        continue

    # Skip only the initial repository navigation cell
    if source.strip() == "%cd /content/Medical-RAG-Hallucination-Detection":
        continue

    print(f"Running Notebook 3 Cell {i + 1}...")

    # run_cell supports Jupyter/Colab commands such as %cd
    get_ipython().run_cell(source)

print("\n✅ Existing Notebook 3 pipeline restored.")
# Out:
# /content/Medical-RAG-Hallucination-Detection
# Restoring existing Notebook 3 pipeline...
#
# Running Notebook 3 Cell 3...
# Dataset: True
# Raw: True
# Files: ['niddk_guiding_principles_diabetes.pdf']
# Running Notebook 3 Cell 5...
# ['niddk_guiding_principles_diabetes.pdf']
# Running Notebook 3 Cell 7...
# /content/Medical-RAG-Hallucination-Detection
# ['niddk_guiding_principles_diabetes.pdf']
# Running Notebook 3 Cell 8...
# Number of pages: 83
# Running Notebook 3 Cell 9...
# Characters extracted: 201724
#
# First 3000 characters:
#
# 1
# Guiding Principles
# for the Care of People with or at Risk for Diabetes
# 2
# Supporting Organizations
# The Guiding Principles for the Care of People with or at Risk for Diabetes was produced by the
# National Diabetes Education Program (NDEP),* a federally funded program sponsored by the
# U.S. Department of Health and Human Services’ National Institutes of Health and Centers for
# Disease Control and Prevention. NDEP’s partnership network includes more than 200 partners
# working together to improve the treatment and outcomes for people with diabetes, promote early
# diagnosis, and prevent or delay the onset of type 2 diabetes. The following organizations support
# the use of the Guiding Principles for the Care of People with or at Risk for Diabetes:
# • Academy of Nutrition and Dietetics
# • American Academy of Family Physicians
# • American Academy of Physician Assistants
# • American Association of Clinical Endocrinologists
# • American Association of Nurse Practitioners
# • American College of Obstetrics and Gynecologists
# • American Diabetes Association
# • American Geriatrics Society
# • American Heart Association
# • American Optometric Association
# • American Osteopathic Association
# • American Podiatric Medical Association
# • American Society for Metabolic and Bariatric Surgery
# • Association of Diabetes Care and Education Specialists
# • Endocrine Society
# • National Council of Asian Pacific Islander Physicians and AANHPI Diabetes Coalition
# • National Human Genome Research Institute
# • National Institute on Deafness and Other Communication Disorders
# • National Institute on Minority Health and Health Disparities
# • Obesity Medicine Association
# • Texas Diabetes Council
# • The Obesity Society
# * The National Diabetes Education Program (NDEP) was retired in 2019 after more than 20 years
# of collaborative partnership between the National Institute of Diabetes and Digestive and Kidney
# Diseases (NIDDK) and the Centers for Disease Control and Prevention (CDC), plus a network of
# more than 200 individuals and organizations. NDEP was successful in coalescing the diabetes
# community at the national level and raising awareness about diabetes prevention and manage­
# ment. Going forward, NIDDK will continue to advance science-based information and resources
# on diabetes.
# GUIDING PRINCIPLES FOR THE CARE OF PEOPLE WITH OR AT RISK FOR DIABETES | SUPPORTING ORGANIZATIONS
# 3
# Acknowledgments
# Many National Diabetes Education Program (NDEP) partners contributed to the 2018 update
# of the Guiding Principles for the Care of People with or at Risk for Diabetes. A core writing and
# review team helped research, write, and refine content drafts. Their dedication and assistance
# were invaluable.
# • Farhad Zangeneh, M.D., FACP, FACE, American Association of Clinical Endocrinologists
# • John Boltri, M.D., FAAFP, American Academy of Family Physicians
# • Apostolos Dallas, M.D., FACP, American College of Physicians
# • Erika Gebel Berg, Ph.D., American Diabetes Association
# • Carol Mangione, M.D., M.S.P.H., FACP, Ameri
# Running Notebook 3 Cell 10...
# Total characters: 201724
# Total words: 28529
# First 1000 characters:
# 1
# Guiding Principles
# for the Care of People with or at Risk for Diabetes
# 2
# Supporting Organizations
# The Guiding Principles for the Care of People with or at Risk for Diabetes was produced by the
# National Diabetes Education Program (NDEP),* a federally funded program sponsored by the
# U.S. Department of Health and Human Services’ National Institutes of Health and Centers for
# Disease Control and Prevention. NDEP’s partnership network includes more than 200 partners
# working together to improve the treatment and outcomes for people with diabetes, promote early
# diagnosis, and prevent or delay the onset of type 2 diabetes. The following organizations support
# the use of the Guiding Principles for the Care of People with or at Risk for Diabetes:
# • Academy of Nutrition and Dietetics
# • American Academy of Family Physicians
# • American Academy of Physician Assistants
# • American Association of Clinical Endocrinologists
# • American Association of Nurse Practitioners
# • American College of Obstetr
# Running Notebook 3 Cell 11...
# Total pages processed: 83
# Running Notebook 3 Cell 12...
# Page number: 1
# Characters: 72
#
# Page text:
#
# 1
# Guiding Principles
# for the Care of People with or at Risk for Diabetes
# Running Notebook 3 Cell 13...
# Cleaning completed.
# Running Notebook 3 Cell 14...
# Original characters: 72
# Cleaned characters: 72
#
# Cleaned page preview:
#
# 1
# Guiding Principles
# for the Care of People with or at Risk for Diabetes
# Running Notebook 3 Cell 16...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2004/1497544838.py in <cell line: 0>()
# ----> 1 from langchain_text_splitters import RecursiveCharacterTextSplitter
#       2
#       3 splitter = RecursiveCharacterTextSplitter(
#       4     chunk_size=1000,
#       5     chunk_overlap=200
#
# ModuleNotFoundError: No module named 'langchain_text_splitters'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
# Running Notebook 3 Cell 17...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2004/1396325653.py in <cell line: 0>()
#       2
#       3 for page in pages:
# ----> 4     page_chunks = splitter.split_text(page["clean_text"])
#       5
#       6     for chunk_id, chunk in enumerate(page_chunks):
#
# NameError: name 'splitter' is not defined
# Running Notebook 3 Cell 18...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_2004/148502639.py in <cell line: 0>()
# ----> 1 print("Chunk ID:", chunks[0]["chunk_id"])
#       2 print("Page:", chunks[0]["page"])
#       3 print("Characters:", len(chunks[0]["text"]))
#       4 print("\nChunk:\n")
#       5 print(chunks[0]["text"])
#
# IndexError: list index out of range
# Running Notebook 3 Cell 19...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_2004/3279109013.py in <cell line: 0>()
# ----> 1 print("Chunk ID:", chunks[100]["chunk_id"])
#       2 print("Page:", chunks[100]["page"])
#       3 print("Characters:", len(chunks[100]["text"]))
#       4 print("\nChunk:\n")
#       5 print(chunks[100]["text"])
#
# IndexError: list index out of range
# Running Notebook 3 Cell 20...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Embedding model loaded successfully!
# Running Notebook 3 Cell 21...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_2004/3339714688.py in <cell line: 0>()
# ----> 1 test_embedding = embedding_model.encode(chunks[0]["text"])
#       2
#       3 print("Embedding type:", type(test_embedding))
#       4 print("Embedding dimensions:", len(test_embedding))
#
# IndexError: list index out of range
# Running Notebook 3 Cell 22...
# Batches: 0it [00:00, ?it/s]
# Total embeddings: 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_2004/2599817416.py in <cell line: 0>()
#       7
#       8 print("Total embeddings:", len(embeddings))
# ----> 9 print("Embedding dimensions:", embeddings.shape[1])
#
# IndexError: tuple index out of range
# Running Notebook 3 Cell 24...
# Embedding shape: (0,)
# Running Notebook 3 Cell 25...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_2004/1228071690.py in <cell line: 0>()
# ----> 1 dimension = embedding_array.shape[1]
#       2
#       3 index = faiss.IndexFlatL2(dimension)
#       4 index.add(embedding_array)
#       5
#
# IndexError: tuple index out of range
# Running Notebook 3 Cell 26...
# Query embedding shape: (1, 384)
# Running Notebook 3 Cell 27...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2004/400377213.py in <cell line: 0>()
# ----> 1 distances, indices = index.search(query_embedding, k=5)
#       2
#       3 print("Retrieved indices:", indices[0])
#       4 print("Distances:", distances[0])
#
# NameError: name 'index' is not defined
# Running Notebook 3 Cell 28...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2004/3962968083.py in <cell line: 0>()
# ----> 1 for rank, idx in enumerate(indices[0], start=1):
#       2     print(f"\n--- Result {rank} ---")
#       3     print("Chunk ID:", chunks[idx]["chunk_id"])
#       4     print("Page:", chunks[idx]["page"])
#       5     print("Distance:", distances[0][rank - 1])
#
# NameError: name 'indices' is not defined
# ✅ Existing Notebook 3 pipeline restored.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2004/1407318800.py in <cell line: 0>()
# ----> 1 from langchain_text_splitters import RecursiveCharacterTextSplitter
#
# ModuleNotFoundError: No module named 'langchain_text_splitters'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2004/2810962981.py in <cell line: 0>()
# ----> 1 from langchain_text_splitters import RecursiveCharacterTextSplitter
#
# ModuleNotFoundError: No module named 'langchain_text_splitters'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Pure Python text chunking
# No LangChain

CHUNK_SIZE = 1000
CHUNK_OVERLAP = 200

def create_chunks(text, chunk_size=1000, chunk_overlap=200):
    chunks = []

    start = 0
    text_length = len(text)

    while start < text_length:
        end = start + chunk_size

        chunk = text[start:end].strip()

        if chunk:
            chunks.append(chunk)

        start += chunk_size - chunk_overlap

    return chunks

print("✅ Pure Python chunking function ready")
print("Chunk size:", CHUNK_SIZE)
print("Chunk overlap:", CHUNK_OVERLAP)
# Out:
# ✅ Pure Python chunking function ready
# Chunk size: 1000
# Chunk overlap: 200

# %%
# Create page-aware chunks using pure Python

chunks = []

for page in pages:
    page_chunks = create_chunks(
        page["clean_text"],
        chunk_size=CHUNK_SIZE,
        chunk_overlap=CHUNK_OVERLAP
    )

    for chunk_id, chunk_text in enumerate(page_chunks):
        chunks.append({
            "chunk_id": f"page_{page['page']}_chunk_{chunk_id}",
            "page": page["page"],
            "text": chunk_text
        })

print("✅ Chunking completed")
print("Total chunks:", len(chunks))
# Out:
# ✅ Chunking completed
# Total chunks: 286

# %%
# Verify first chunk

print("Chunk ID:", chunks[0]["chunk_id"])
print("Page:", chunks[0]["page"])
print("Characters:", len(chunks[0]["text"]))

print("\nFirst chunk:")
print("--------------------")
print(chunks[0]["text"])
# Out:
# Chunk ID: page_1_chunk_0
# Page: 1
# Characters: 72
#
# First chunk:
# --------------------
# 1
# Guiding Principles
# for the Care of People with or at Risk for Diabetes

# %%
# Generate embeddings for all chunks

chunk_texts = [chunk["text"] for chunk in chunks]

embeddings = embedding_model.encode(
    chunk_texts,
    show_progress_bar=True
)

print("✅ Embeddings generated")
print("Total embeddings:", len(embeddings))
print("Embedding dimensions:", embeddings.shape[1])
# Out:
# Batches:   0%|          | 0/9 [00:00<?, ?it/s]
# ✅ Embeddings generated
# Total embeddings: 286
# Embedding dimensions: 384

# %%
# ============================================
# RAG RETRIEVAL TEST
# ============================================

question = "What are the risk factors for diabetes?"

# Convert question into embedding
query_embedding = embedding_model.encode(
    [question]
).astype("float32")

# Search FAISS
k = 5

distances, indices = index.search(
    query_embedding,
    k
)

print("Question:", question)
print("\nRetrieved chunks:")
print("=" * 60)

for rank, idx in enumerate(indices[0], start=1):
    print(f"\n--- Result {rank} ---")
    print("Chunk ID:", chunks[idx]["chunk_id"])
    print("Page:", chunks[idx]["page"])
    print("Distance:", distances[0][rank - 1])
    print("Text:")
    print(chunks[idx]["text"][:500])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2004/196085102.py in <cell line: 0>()
#      13 k = 5
#      14
# ---> 15 distances, indices = index.search(
#      16     query_embedding,
#      17     k
#
# NameError: name 'index' is not defined

# %%
# ============================================
# CREATE FAISS INDEX
# ============================================

import faiss
import numpy as np

# Convert embeddings to float32
embedding_array = np.asarray(embeddings).astype("float32")

# Get embedding dimension
dimension = embedding_array.shape[1]

# Create FAISS index
index = faiss.IndexFlatL2(dimension)

# Add embeddings to index
index.add(embedding_array)

print("✅ FAISS index created successfully")
print("Embedding shape:", embedding_array.shape)
print("Vector dimension:", dimension)
print("Total vectors:", index.ntotal)
# Out:
# ✅ FAISS index created successfully
# Embedding shape: (286, 384)
# Vector dimension: 384
# Total vectors: 286

# %%
# ============================================
# GENERATE EMBEDDINGS
# ============================================

chunk_texts = [chunk["text"] for chunk in chunks]

embeddings = embedding_model.encode(
    chunk_texts,
    show_progress_bar=True
)

print("✅ Embeddings generated")
print("Total embeddings:", len(embeddings))
print("Embedding dimensions:", embeddings.shape[1])
# Out:
# Batches:   0%|          | 0/9 [00:00<?, ?it/s]
# ✅ Embeddings generated
# Total embeddings: 286
# Embedding dimensions: 384

# %%
# ============================================
# CREATE FAISS VECTOR INDEX
# ============================================

import faiss
import numpy as np

embedding_array = np.asarray(embeddings).astype("float32")

dimension = embedding_array.shape[1]

index = faiss.IndexFlatL2(dimension)
index.add(embedding_array)

print("✅ FAISS index ready")
print("Total chunks:", len(chunks))
print("Vector dimension:", dimension)
print("FAISS vectors:", index.ntotal)
# Out:
# ✅ FAISS index ready
# Total chunks: 286
# Vector dimension: 384
# FAISS vectors: 286

# %%
# ============================================
# FAISS RETRIEVAL FUNCTION
# ============================================

def retrieve_documents(question, top_k=5):
    """
    Retrieve the most relevant medical chunks
    from the FAISS index.
    """

    query_embedding = embedding_model.encode(
        [question]
    ).astype("float32")

    distances, indices = index.search(
        query_embedding,
        top_k
    )

    results = []

    for rank, idx in enumerate(indices[0], start=1):

        results.append({
            "rank": rank,
            "chunk_id": chunks[idx]["chunk_id"],
            "page": chunks[idx]["page"],
            "text": chunks[idx]["text"],
            "distance": float(distances[0][rank - 1])
        })

    return results


print("✅ Retrieval function created")
# Out:
# ✅ Retrieval function created

# %%
# ============================================
# TEST RETRIEVAL
# ============================================

question = "What are the risk factors for diabetes?"

retrieved_docs = retrieve_documents(
    question,
    top_k=5
)

print("Question:", question)
print("=" * 70)

for doc in retrieved_docs:

    print(f"\n--- Result {doc['rank']} ---")
    print("Page:", doc["page"])
    print("Distance:", doc["distance"])
    print("Chunk ID:", doc["chunk_id"])
    print(doc["text"][:700])
# Out:
# Question: What are the risk factors for diabetes?
# ======================================================================
#
# --- Result 1 ---
# Page: 15
# Distance: 0.5615706443786621
# Chunk ID: page_15_chunk_4
# AT RISK FOR DIABETES | PRINCIPLE 2
#
# --- Result 2 ---
# Page: 5
# Distance: 0.6615881323814392
# Chunk ID: page_5_chunk_0
# 5
# INTRODUCTION
# The diabetes problem
# Today, 30.3 million people (9.4 percent of the U.S. population) have diabetes, including 7.2 million
# who are undiagnosed.1 A major cause of blindness, renal failure, and amputation, diabetes
# also increases the risk of cardiovascular disease, cancer, and dementia and more than doubles
# individual health care costs.2 The total estimated cost of diagnosed diabetes in 2017 was $327
# billion, including $237 billion in direct medical costs and $90 billion in reduced productivity.2
# Another 84.1 million Americans (33.9 percent of adults) have glucose levels that are higher than
# normal but not high enough to be characterized as diabetes.1 Because persons with these g
#
# --- Result 3 ---
# Page: 75
# Distance: 0.6786355972290039
# Chunk ID: page_75_chunk_4
# diabetes have more than two CVD risk factors.9,10 Overweight and obesity in children are
# GUIDING PRINCIPLES FOR THE CARE OF PEOPLE WITH OR AT RISK FOR DIABETES | PRINCIPLE 10
#
# --- Result 4 ---
# Page: 1
# Distance: 0.7497812509536743
# Chunk ID: page_1_chunk_0
# 1
# Guiding Principles
# for the Care of People with or at Risk for Diabetes
#
# --- Result 5 ---
# Page: 5
# Distance: 0.7562639713287354
# Chunk ID: page_5_chunk_1
# tes
# by the Centers for Disease Control and Prevention (CDC) and other organizations.
# Proper nutrition and physical activity are the cornerstones of treatment and prevention of type 2
# diabetes. In addition to lifestyle modifications and tobacco avoidance, controlling blood glucose,
# blood pressure, and cholesterol dramatically improves health outcomes. As a result of improved
# risk factor control, rates of complications, particularly for cardiovascular disease, have declined
# among people with diabetes.3
# Yet diabetes management is suboptimal, particularly in disproportionately affected poor and
# minority populations.4 Analysis of national survey data from 1999 to 2010 for adults with diabetes
# fou

# %%
# ============================================
# BUILD MEDICAL CONTEXT
# ============================================

def build_context(retrieved_docs):

    context_parts = []

    for doc in retrieved_docs:

        context_parts.append(
            f"""[Source Page {doc['page']}]
{doc['text']}"""
        )

    return "\n\n".join(context_parts)


context = build_context(retrieved_docs)

print("✅ Medical context created")
print(context)
# Out:
# ✅ Medical context created
# [Source Page 15]
# AT RISK FOR DIABETES | PRINCIPLE 2
#
# [Source Page 5]
# 5
# INTRODUCTION
# The diabetes problem
# Today, 30.3 million people (9.4 percent of the U.S. population) have diabetes, including 7.2 million
# who are undiagnosed.1 A major cause of blindness, renal failure, and amputation, diabetes
# also increases the risk of cardiovascular disease, cancer, and dementia and more than doubles
# individual health care costs.2 The total estimated cost of diagnosed diabetes in 2017 was $327
# billion, including $237 billion in direct medical costs and $90 billion in reduced productivity.2
# Another 84.1 million Americans (33.9 percent of adults) have glucose levels that are higher than
# normal but not high enough to be characterized as diabetes.1 Because persons with these glucose
# levels are at increased risk of developing type 2 diabetes, this condition is termed prediabetes
# by the Centers for Disease Control and Prevention (CDC) and other organizations.
# Proper nutrition and physical activity are the cornerstones of treatment and prevention of type 2
# diabetes. In addi
#
# [Source Page 75]
# diabetes have more than two CVD risk factors.9,10 Overweight and obesity in children are
# GUIDING PRINCIPLES FOR THE CARE OF PEOPLE WITH OR AT RISK FOR DIABETES | PRINCIPLE 10
#
# [Source Page 1]
# 1
# Guiding Principles
# for the Care of People with or at Risk for Diabetes
#
# [Source Page 5]
# tes
# by the Centers for Disease Control and Prevention (CDC) and other organizations.
# Proper nutrition and physical activity are the cornerstones of treatment and prevention of type 2
# diabetes. In addition to lifestyle modifications and tobacco avoidance, controlling blood glucose,
# blood pressure, and cholesterol dramatically improves health outcomes. As a result of improved
# risk factor control, rates of complications, particularly for cardiovascular disease, have declined
# among people with diabetes.3
# Yet diabetes management is suboptimal, particularly in disproportionately affected poor and
# minority populations.4 Analysis of national survey data from 1999 to 2010 for adults with diabetes
# found improvement in glycemic control, blood pressure, and blood lipids. However, 22 percent
# of adults with diabetes have A1C > 8; 28 percent have BP > 140/90; 51 percent are on statins; 44
# percent have LDL > 100; and 20 percent use tobacco. Thus, a substantial proportion of people with
# diabetes do not

# %%
# ============================================
# GEMINI CLIENT
# ============================================

from google.colab import userdata
from google import genai

API_KEY = userdata.get("GEMINI_API_KEY")

if not API_KEY:
    raise ValueError(
        "GEMINI_API_KEY not found in Colab Secrets"
    )

client = genai.Client(
    api_key=API_KEY
)

print("✅ Gemini client initialized")
# Out:
# ✅ Gemini client initialized

# %%
# ============================================
# GROUNDED MEDICAL PROMPT
# ============================================

def create_grounded_prompt(question, context):

    prompt = f"""
You are a medical information assistant operating
inside a Retrieval-Augmented Generation (RAG) system.

Answer the user's question ONLY using the provided
medical evidence.

STRICT RULES:

1. Use only information contained in the evidence.
2. Do not use outside knowledge.
3. Do not invent facts.
4. Do not make unsupported medical claims.
5. If the evidence is insufficient, clearly state:
   "The provided document does not contain sufficient
   evidence to answer this question."
6. Mention relevant source page numbers.
7. Do not provide personalized diagnosis.
8. Do not provide personalized treatment instructions.
9. Keep the answer clear and understandable.

USER QUESTION:
{question}

MEDICAL EVIDENCE:
{context}

ANSWER:
"""

    return prompt


prompt = create_grounded_prompt(
    question,
    context
)

print(prompt)
# Out:
# You are a medical information assistant operating
# inside a Retrieval-Augmented Generation (RAG) system.
#
# Answer the user's question ONLY using the provided
# medical evidence.
#
# STRICT RULES:
#
# 1. Use only information contained in the evidence.
# 2. Do not use outside knowledge.
# 3. Do not invent facts.
# 4. Do not make unsupported medical claims.
# 5. If the evidence is insufficient, clearly state:
#    "The provided document does not contain sufficient
#    evidence to answer this question."
# 6. Mention relevant source page numbers.
# 7. Do not provide personalized diagnosis.
# 8. Do not provide personalized treatment instructions.
# 9. Keep the answer clear and understandable.
#
# USER QUESTION:
# What are the risk factors for diabetes?
#
# MEDICAL EVIDENCE:
# [Source Page 15]
# AT RISK FOR DIABETES | PRINCIPLE 2
#
# [Source Page 5]
# 5
# INTRODUCTION
# The diabetes problem
# Today, 30.3 million people (9.4 percent of the U.S. population) have diabetes, including 7.2 million
# who are undiagnosed.1 A major cause of blindness, renal failure, and amputation, diabetes
# also increases the risk of cardiovascular disease, cancer, and dementia and more than doubles
# individual health care costs.2 The total estimated cost of diagnosed diabetes in 2017 was $327
# billion, including $237 billion in direct medical costs and $90 billion in reduced productivity.2
# Another 84.1 million Americans (33.9 percent of adults) have glucose levels that are higher than
# normal but not high enough to be characterized as diabetes.1 Because persons with these glucose
# levels are at increased risk of developing type 2 diabetes, this condition is termed prediabetes
# by the Centers for Disease Control and Prevention (CDC) and other organizations.
# Proper nutrition and physical activity are the cornerstones of treatment and prevention of type 2
# diabetes. In addi
#
# [Source Page 75]
# diabetes have more than two CVD risk factors.9,10 Overweight and obesity in children are
# GUIDING PRINCIPLES FOR THE CARE OF PEOPLE WITH OR AT RISK FOR DIABETES | PRINCIPLE 10
#
# [Source Page 1]
# 1
# Guiding Principles
# for the Care of People with or at Risk for Diabetes
#
# [Source Page 5]
# tes
# by the Centers for Disease Control and Prevention (CDC) and other organizations.
# Proper nutrition and physical activity are the cornerstones of treatment and prevention of type 2
# diabetes. In addition to lifestyle modifications and tobacco avoidance, controlling blood glucose,
# blood pressure, and cholesterol dramatically improves health outcomes. As a result of improved
# risk factor control, rates of complications, particularly for cardiovascular disease, have declined
# among people with diabetes.3
# Yet diabetes management is suboptimal, particularly in disproportionately affected poor and
# minority populations.4 Analysis of national survey data from 1999 to 2010 for adults with diabetes
# found improvement in glycemic control, blood pressure, and blood lipids. However, 22 percent
# of adults with diabetes have A1C > 8; 28 percent have BP > 140/90; 51 percent are on statins; 44
# percent have LDL > 100; and 20 percent use tobacco. Thus, a substantial proportion of people with
# diabetes do not
#
# ANSWER:

# %%
# ============================================
# GEMINI RESPONSE
# ============================================

response = client.models.generate_content(
    model="gemini-3.1-flash-lite",
    contents=prompt
)

answer = response.text

print("QUESTION")
print(question)

print("\nANSWER")
print("=" * 70)
print(answer)
# Out:
# QUESTION
# What are the risk factors for diabetes?
#
# ANSWER
# ======================================================================
# Based on the provided documents, the following information regarding risk factors for diabetes is available:
#
# *   **Glucose levels:** Individuals with glucose levels that are higher than normal, but not high enough to be classified as diabetes, are at an increased risk of developing type 2 diabetes (Source Page 5).
# *   **Obesity/Overweight:** Overweight and obesity in children are identified as risk factors (Source Page 75).
#
# The provided document does not contain a comprehensive list of all risk factors for diabetes.

# %%
# ============================================
# COMPLETE MEDICAL RAG PIPELINE
# ============================================

def medical_rag(question, top_k=5):

    # ----------------------------------------
    # 1. Retrieve documents
    # ----------------------------------------

    retrieved_docs = retrieve_documents(
        question,
        top_k=top_k
    )

    # ----------------------------------------
    # 2. Build context
    # ----------------------------------------

    context = build_context(
        retrieved_docs
    )

    # ----------------------------------------
    # 3. Create grounded prompt
    # ----------------------------------------

    prompt = create_grounded_prompt(
        question,
        context
    )

    # ----------------------------------------
    # 4. Generate answer
    # ----------------------------------------

    response = client.models.generate_content(
        model="gemini-3.1-flash-lite",
        contents=prompt
    )

    # ----------------------------------------
    # 5. Return structured result
    # ----------------------------------------

    return {
        "question": question,
        "answer": response.text,
        "retrieved_documents": retrieved_docs
    }


print("✅ Complete Medical RAG pipeline created")
# Out:
# ✅ Complete Medical RAG pipeline created

# %%
# ============================================
# COMPLETE RAG TEST
# ============================================

result = medical_rag(
    "What are the risk factors for diabetes?"
)

print("QUESTION:")
print(result["question"])

print("\nANSWER:")
print("=" * 70)
print(result["answer"])

print("\nSOURCE PAGES:")

pages_used = sorted(
    set(
        doc["page"]
        for doc in result["retrieved_documents"]
    )
)

print(pages_used)
# Out:
# QUESTION:
# What are the risk factors for diabetes?
#
# ANSWER:
# ======================================================================
# Based on the provided documents, the following information regarding risk factors for diabetes is available:
#
# *   **Glucose levels:** Individuals with glucose levels that are higher than normal but not high enough to be classified as diabetes—a condition termed prediabetes—are at an increased risk of developing type 2 diabetes (Source Page 5).
# *   **Obesity/Overweight:** Overweight and obesity in children are identified as risk factors associated with diabetes (Source Page 75).
#
# The provided documents do not contain sufficient evidence to provide a comprehensive list of all risk factors for diabetes.
#
# SOURCE PAGES:
# [1, 5, 15, 75]

# %%
# ============================================
# TEST INSUFFICIENT EVIDENCE
# ============================================

test_question = "What is the capital of France?"

result_test = medical_rag(
    test_question
)

print("QUESTION:")
print(result_test["question"])

print("\nANSWER:")
print("=" * 70)
print(result_test["answer"])

print("\nRETRIEVED PAGES:")

print(
    sorted(
        set(
            doc["page"]
            for doc in result_test["retrieved_documents"]
        )
    )
)
# Out:
# QUESTION:
# What is the capital of France?
#
# ANSWER:
# ======================================================================
# The provided document does not contain sufficient evidence to answer this question.
#
# RETRIEVED PAGES:
# [11, 25, 42, 52, 56]

# %%
# %cd /content/Medical-RAG-Hallucination-Detection

# !ls notebooks
# Out:
# /content/Medical-RAG-Hallucination-Detection
# Notebook_01_Project_Setup.ipynb      Notebook_03_PDF_Text_Extraction.ipynb
# Notebook_02_Environment_Setup.ipynb  Notebook_04_LLM_Integration.ipynb

# %%
# %cd /content/Medical-RAG-Hallucination-Detection

# !git status
# Out:
# /content/Medical-RAG-Hallucination-Detection
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# %cd /content/Medical-RAG-Hallucination-Detection

# !ls -lh notebooks/
# Out:
# /content/Medical-RAG-Hallucination-Detection
# total 508K
# -rw-r--r-- 1 root root 7.3K Sep  4 12:55 Notebook_01_Project_Setup.ipynb
# -rw-r--r-- 1 root root 9.5K Sep  4 12:55 Notebook_02_Environment_Setup.ipynb
# -rw-r--r-- 1 root root 227K Sep  4 12:55 Notebook_03_PDF_Text_Extraction.ipynb
# -rw-r--r-- 1 root root 260K Sep  4 12:55 Notebook_04_LLM_Integration.ipynb

# %%
# !ls -lh notebooks/Notebook_04_LLM_Integration.ipynb
# Out:
# -rw-r--r-- 1 root root 260K Sep  4 12:55 notebooks/Notebook_04_LLM_Integration.ipynb

# %%
# %cd /content/Medical-RAG-Hallucination-Detection

# !git status
# !git log -1 --oneline
# Out:
# /content/Medical-RAG-Hallucination-Detection
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# 196d8e6 (HEAD -> main, origin/main, origin/HEAD) Remove duplicate Notebook 4 from root

# %%
# %cd /content/Medical-RAG-Hallucination-Detection
# !git status
# Out:
# /content/Medical-RAG-Hallucination-Detection
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# %cd /content/Medical-RAG-Hallucination-Detection
# !git status
# Out:
# /content/Medical-RAG-Hallucination-Detection
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git commit -m "Complete Notebook 4 LLM integration"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@6472ca840019.(none)')

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote -v
# Out:
# origin	https://github.com/vivek28n/Medical-RAG-Hallucination-Detection.git (fetch)
# origin	https://github.com/vivek28n/Medical-RAG-Hallucination-Detection.git (push)

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
import os

print(os.path.abspath("Notebook_04_LLM_Integration.ipynb"))
# Out:
# /content/Medical-RAG-Hallucination-Detection/Notebook_04_LLM_Integration.ipynb

# %%
# !pwd
# !ls -lh Notebook_04_LLM_Integration.ipynb
# Out:
# /content/Medical-RAG-Hallucination-Detection
# ls: cannot access 'Notebook_04_LLM_Integration.ipynb': No such file or directory

# %%
from google.colab import drive

# %%
import os
print(os.getcwd())
print(os.listdir('/content')[:20])
# Out:
# /content/Medical-RAG-Hallucination-Detection
# ['.config', 'Medical-RAG-Hallucination-Detection', 'sample_data']
