# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek28n/Medical-RAG-Hallucination-Detection/blob/main/notebooks/Notebook_02_Environment_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Environment Setup
#
# This notebook verifies and prepares the Python environment
# for the Medical RAG Hallucination Detection project.
#
# **Authors:** Vivek, Mansi

# %%
import sys

print("Python version:")
print(sys.version)
# Out:
# Python version:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
import platform

print("Python:", platform.python_version())
print("Operating System:", platform.system())
print("Machine:", platform.machine())
# Out:
# Python: 3.12.13
# Operating System: Linux
# Machine: x86_64

# %%
import torch

print("PyTorch version:", torch.__version__)
print("GPU available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("GPU: Not available")
# Out:
# PyTorch version: 2.11.0+cpu
# GPU available: False
# GPU: Not available

# %%
# !pip install -q \
    langchain \
    langchain-community \
    faiss-cpu \
    sentence-transformers \
    pymupdf \
    pypdf \
    fastapi \
    uvicorn
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 53.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 101.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 86.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.1/378.1 kB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 64.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 8.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
import torch

print("PyTorch version:", torch.__version__)
print("GPU available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch version: 2.11.0+cu128
# GPU available: True
# GPU: Tesla T4

# %%
import langchain
import faiss
import sentence_transformers
import fitz
import pypdf
import fastapi

print("All required libraries imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_741/1544781153.py in <cell line: 0>()
#       1 import langchain
#       2 import faiss
# ----> 3 import sentence_transformers
#       4 import fitz
#       5 import pypdf
#
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/__init__.py in <module>
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.base.sampler import DefaultBatchSampler, MultiDatasetDefaultBatchSampler
#      16 from sentence_transformers.cross_encoder import (
#      17     CrossEncoder,
#
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/base/__init__.py in <module>
#       2
#       3 from .data_collator import BaseDataCollator
# ----> 4 from .model import BaseModel
#       5 from .peft_mixin import PeftAdapterMixin
#       6 from .sampler import (
#
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/base/model.py in <module>
#      22 from packaging import version
#      23 from torch import Tensor, nn
# ---> 24 from transformers import PreTrainedModel, is_datasets_available, is_torch_npu_available
#      25 from transformers.dynamic_module_utils import get_relative_import_files
#      26 from transformers.utils import logging as transformers_logging
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    2303         elif name in self._class_to_module:
#    2304             try:
# -> 2305                 module = self._get_module(self._class_to_module[name])
#    2306                 value = getattr(module, name)
#    2307             except (ModuleNotFoundError, RuntimeError, AttributeError) as e:
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    2535     def _get_module(self, module_name: str):
#    2536         try:
# -> 2537             return importlib.import_module("." + module_name, self.__name__)
#    2538         except Exception as e:
#    2539             raise e
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py in <module>
#      67 from .integrations.deepspeed import _load_state_dict_into_zero3_model
#      68 from .integrations.eager_paged import eager_paged_attention_forward
# ---> 69 from .integrations.finegrained_fp8 import ALL_FP8_EXPERTS_FUNCTIONS
#      70 from .integrations.flash_attention import flash_attention_forward
#      71 from .integrations.flash_paged import paged_attention_forward
#
# /usr/local/lib/python3.12/dist-packages/transformers/integrations/finegrained_fp8.py in <module>
#      33     is_torchdynamo_compiling,
#      34 )
# ---> 35 from .deepgemm import (
#      36     deepgemm_fp8_fp4_experts_forward,
#      37     deepgemm_fp8_fp4_linear,
#
# /usr/local/lib/python3.12/dist-packages/transformers/integrations/deepgemm.py in <module>
#     164
#     165
# --> 166 @torch._dynamo.allow_in_graph
#     167 def _populate_deepgemm_kernel(requires_sm100: bool = False) -> None:
#     168     _ = _load_deepgemm_kernel(requires_sm100=requires_sm100)
#
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py in __getattr__(name)
#    2877         # Lazy modules
#    2878         if name in _lazy_modules:
# -> 2879             return importlib.import_module(f".{name}", __name__)
#    2880
#    2881         raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/__init__.py in <module>
#      11 import torch
#      12
# ---> 13 from . import (
#      14     aot_compile,
#      15     config,
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/aot_compile.py in <module>
#      13 import torch
#      14 import torch.fx
# ---> 15 from torch._dynamo.convert_frame import GraphRuntimeEnv
#      16 from torch._dynamo.graph_utils import _graph_device_type
#      17 from torch._dynamo.package import SystemInfo
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/convert_frame.py in <module>
#      60 from torch._dynamo.callback import CallbackTrigger
#      61 from torch._dynamo.distributed import get_compile_pg
# ---> 62 from torch._dynamo.symbolic_convert import TensorifyState
#      63 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      64 from torch._logging import structured
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/symbolic_convert.py in <module>
#      52 import torch._logging
#      53 from torch._dynamo.dynamo_profiler import DynamoProfilerState, FunctionTraceTiming
# ---> 54 from torch._dynamo.exc import ObservedException, TensorifyScalarRestartAnalysis
#      55 from torch._guards import InlinedCodeCache, tracing, TracingContext
#      56 from torch._logging.structured import dump_file
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/exc.py in <module>
#      42
#      43 from . import config
# ---> 44 from .utils import counters
#      45
#      46
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/utils.py in <module>
#      68 import torch
#      69 import torch._functorch.config
# ---> 70 import torch.fx.experimental.symbolic_shapes
#      71 import torch.utils._pytree as pytree
#      72 from torch import fx
#
# /usr/local/lib/python3.12/dist-packages/torch/fx/experimental/symbolic_shapes.py in <module>
#       1 from __future__ import annotations
#       2
# ----> 3 import sympy
#       4 from sympy import S
#       5
#
# /usr/local/lib/python3.12/dist-packages/sympy/__init__.py in <module>
#      75         assuming, Q, ask, register_handler, remove_handler, refine)
#      76
# ---> 77 from .polys import (Poly, PurePoly, poly_from_expr, parallel_poly_from_expr,
#      78         degree, total_degree, degree_list, LC, LM, LT, pdiv, prem, pquo,
#      79         pexquo, div, rem, quo, exquo, half_gcdex, gcdex, invert,
#
# /usr/local/lib/python3.12/dist-packages/sympy/polys/__init__.py in <module>
#      66 ]
#      67
# ---> 68 from .polytools import (Poly, PurePoly, poly_from_expr,
#      69         parallel_poly_from_expr, degree, total_degree, degree_list, LC, LM,
#      70         LT, pdiv, prem, pquo, pexquo, div, rem, quo, exquo, half_gcdex, gcdex,
#
# /usr/local/lib/python3.12/dist-packages/sympy/polys/polytools.py in <module>
#      27 from sympy.logic.boolalg import BooleanAtom
#      28 from sympy.polys import polyoptions as options
# ---> 29 from sympy.polys.constructor import construct_domain
#      30 from sympy.polys.domains import FF, QQ, ZZ
#      31 from sympy.polys.domains.domainelement import DomainElement
#
# /usr/local/lib/python3.12/dist-packages/sympy/polys/constructor.py in <module>
#       5 from sympy.core.evalf import pure_complex
#       6 from sympy.core.sorting import ordered
# ----> 7 from sympy.polys.domains import ZZ, QQ, ZZ_I, QQ_I, EX
#       8 from sympy.polys.domains.complexfield import ComplexField
#       9 from sympy.polys.domains.realfield import RealField
#
# /usr/local/lib/python3.12/dist-packages/sympy/polys/domains/__init__.py in <module>
#      10
#      11 from .domain import Domain
# ---> 12 from .finitefield import FiniteField, FF, GF
#      13 from .integerring import IntegerRing, ZZ
#      14 from .rationalfield import RationalField, QQ
#
# /usr/local/lib/python3.12/dist-packages/sympy/polys/domains/finitefield.py in <module>
#      14 from sympy.polys.polyerrors import CoercionFailed
#      15 from sympy.utilities import public
# ---> 16 from sympy.polys.domains.groundtypes import SymPyInteger
#      17
#      18
#
# /usr/local/lib/python3.12/dist-packages/sympy/polys/domains/groundtypes.py in <module>
#       8 PythonComplex = builtins.complex
#       9
# ---> 10 from .pythonrational import PythonRational
#      11
#      12 from sympy.core.intfunc import (
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:
