# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek28n/Medical-RAG-Hallucination-Detection/blob/main/notebooks/Notebook_01_Project_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/vivek28n/Medical-RAG-Hallucination-Detection.git
# Out:
# Cloning into 'Medical-RAG-Hallucination-Detection'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 15 (delta 2), reused 10 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 5.57 KiB | 5.57 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# %cd Medical-RAG-Hallucination-Detection
# Out:
# /content/Medical-RAG-Hallucination-Detection

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !ls
# Out:
# assets	 docs	   models     presentation  screenshots  vector_db
# backend  frontend  notebooks  README.md     scripts
# dataset  LICENSE   outputs    research	    tests

# %%
# !ls -la
# Out:
# total 84
# drwxr-xr-x 17 root root 4096 Aug  8 13:58 .
# drwxr-xr-x  1 root root 4096 Aug  8 13:58 ..
# drwxr-xr-x  2 root root 4096 Aug  8 13:58 assets
# drwxr-xr-x  2 root root 4096 Aug  8 13:58 backend
# drwxr-xr-x  2 root root 4096 Aug  8 13:58 dataset
# drwxr-xr-x  2 root root 4096 Aug  8 13:58 docs
# drwxr-xr-x  2 root root 4096 Aug  8 13:58 frontend
# drwxr-xr-x  8 root root 4096 Aug  8 14:00 .git
# -rw-r--r--  1 root root 4628 Aug  8 13:58 .gitignore
# -rw-r--r--  1 root root 1065 Aug  8 13:58 LICENSE
# drwxr-xr-x  2 root root 4096 Aug  8 13:58 models
# drwxr-xr-x  2 root root 4096 Aug  8 13:58 notebooks
# drwxr-xr-x  2 root root 4096 Aug  8 13:58 outputs
# drwxr-xr-x  2 root root 4096 Aug  8 13:58 presentation
# -rw-r--r--  1 root root 1554 Aug  8 13:58 README.md
# drwxr-xr-x  2 root root 4096 Aug  8 13:58 research
# drwxr-xr-x  2 root root 4096 Aug  8 13:58 screenshots
# drwxr-xr-x  2 root root 4096 Aug  8 13:58 scripts
# drwxr-xr-x  2 root root 4096 Aug  8 13:58 tests
# drwxr-xr-x  2 root root 4096 Aug  8 13:58 vector_db

# %%
# !find . -maxdepth 2 -type f
# Out:
# ./backend/.gitkeep
# ./frontend/.gitkeep
# ./notebooks/.gitkeep
# ./models/.gitkeep
# ./presentation/.gitkeep
# ./assets/.gitkeep
# ./.git/config
# ./.git/description
# ./.git/HEAD
# ./.git/index
# ./.git/packed-refs
# ./screenshots/.gitkeep
# ./scripts/.gitkeep
# ./outputs/.gitkeep
# ./research/.gitkeep
# ./LICENSE
# ./README.md
# ./docs/PROJECT_PLAN.md
# ./docs/.gitkeep
# ./docs/ROADMAP.md
# ./docs/TEAM_GUIDELINES.md
# ./.gitignore
# ./vector_db/.gitkeep
# ./tests/.gitkeep
# ./dataset/.gitkeep
